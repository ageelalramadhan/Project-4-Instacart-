# %% [markdown]
# # 01. Importing libraries

# %%
# Importing necessary libraries for this project
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Working with Python data types

# %%
# 7. Three different ways to reach 100 using addition or subtraction
a = 50 + 50
b = 150 - 50
c = 80 + 20

a, b, c

# 8. Two floating-point variables divided by each other
x = 10.5
y = 2.5
x / y

# 9. Construct a short word from separate strings (concatenation)
letter1 = "C"
letter2 = "a"
letter3 = "t"
word = letter1 + letter2 + letter3
word

# 10. Construct two short sentences from separate strings
s1_part1 = "Python "
s1_part2 = "is fun."
sentence1 = s1_part1 + s1_part2

s2_part1 = "Data "
s2_part2 = "analysis is powerful."
sentence2 = s2_part1 + s2_part2

sentence1, sentence2

# BONUS: Make a string appear 100 times
"Hi!" * 100
# Out:
# 'Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!'
